# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya-Saini-1/DataScience_Grras/blob/Python/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Welcome to day 6 (its 1st june, 26)***

# %% [markdown]
# OOPs

# %%
# example
# class priya:
#   def __init__(self,name):
#     self.name = name
#   def show(self):
#     print(self.name)

# r = priya("hello")
# r.show()


# #example 2
# class priya:
#   def __init__(self,name,age):
#     self.name = name
#     self.age = age
#     print(self)

#   def show(self):
#     print(self.name)
#   def getAge(self):
#     print("my age is:", self.age)

#   def getName(self):
#     print("my name is:", self.name)

# p = priya("hello", 23)
# p.show()
# p.getAge()
# p.getName()

# example 3
class student:
  def __init__(self,*args):
    print(type(args))
    print(args)
    self.name = args[0]

  def getStu(self):
    return self.name


s = student("hello", 20, "0909", "happy404,com")
t = s.getStu()
print(t)
# Out:
# <class 'tuple'>
# ('hello', 20, '0909', 'happy404,com')
# hello

# %%
class company:
  def __init__(self, name):
    self.name = name
  def show(self):
    print(self.name)

c = company("Channel")
c.show()

class college:
    def __init__(self, name):
        self.name = name['name']
        self.location = name["location"]
    def getCollege(self):
        print("The college name is: ", self.name)
        print("The college location is: ", self.location)
c = college({"name": "GRASS", "location": "Bangalore"})
c.getCollege()
# Out:
# Channel
# The college name is:  GRASS
# The college location is:  Bangalore

# %%
class student:
  def __init__(self, *args):
    self.data = args

  def users(self):
    # to print dheeraj , kunal
    for i in self.data[0]:
      print(i)
    # to print kunal
    # print(self.data[0][0])
    # print(self.data[0][1])
    pass

  def details(self):
    # to print address = kukas, college = arya
    for i in self.data[1]:
      print(i, ":", self.data[1][i])
    # to print address = kukas, college = arya
    # print("address: " ,self.data[1]["address"])
    # print("college: " ,self.data[1]["college"])
    pass

s = student(["dheeraj", "kunal", "harsh", "praveen"], {"address": "kukas", "college": "Arya", "loc": "jaipur"})
s.users()
s.details()
# Out:
# dheeraj
# kunal
# harsh
# praveen
# address : kukas
# college : Arya
# loc : jaipur

# %%
help(abs)
# Out:
# Help on built-in function abs in module builtins:
#
# abs(x, /)
#     Return the absolute value of the argument.
