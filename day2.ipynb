# %% [markdown]
# <a href="https://colab.research.google.com/github/Priya-Saini-1/DataScience_Grras/blob/Python/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Logical Operator

# %%
# and , or , not

# and
num1 = 10
num2 = 20
print(num1 and num2)

# or
num1 = "helo"
num2 = ""
print(num1 or num2)
print(num2 or num1)

# not
num1 = [] # default [] -> false || [1,2,3] -> true
print(not num1)

#not
num1 = {} # default {} -> false || {name:"hello"} -> true
print(not num1)
# Out:
# 20
# helo
# helo
# True
# True

# %% [markdown]
# Bitwise operator

# %%
# >> , << , & , | , ^

# &
a = 5 # 101
b = 2 # 010
print(a & b)
# Out:
# 0

# %% [markdown]
# Identity operator

# %%
# is | is not

# example 1
# name = 10
# name1 = 10
# print(name == name1 )# value

# print(name is name1) # value | address
# print(id(name))
# print(id(name1))

#example   (-5 to 256) -> both variable point on same address
num1 = [1,2,3]
num2 = [1,2,3]
num3 = num1

print(num1 == num2)

print(num1 is num2)
print(id(num1))
print(id(num2))
print(id(num3))
# Out:
# True
# False
# 139725575736448
# 139725574424192
# 139725575736448

# %% [markdown]
# Conditional Statement

# %%
# if
num1 = 10
num2 = 20
if num1 < num2 :
  print(num2)

# if else
num1 = int(input("enter the number: "))
if num1 :
  print("number:-",num1)
else:
  print("zero",num1)

# if elif else
age = int(input("Enter the number: "))
if age == 18:
  print("your age is: ",age)
elif age > 18 :
  print("your are above then 18 <",age)
else:
  print("you are less than 18 >",age)
# Out:
# 20
# enter the number: 234
# number:- 234
# Enter the number: 3
# you are less than 18 > 3

# %% [markdown]
# Loops

# %%
#for
# for i in range(5):
#   print("i = ",i)

# #for
# for i in range(1,11):
#   print("number = ",i)


# list
l = [11,12,13,14]
# print(len(l))
# for i in range(4):
#   print(l[i])

# for i in range(len(l)):
#   print(l[i])

# for i in l:
#   print(i)

#while
# num1 = int(input("Enter the number: "))
# i = 0
# while i < num1 :
#   print(i)
#   i += 1

# list
# l = [10,11,12,13,14,15]
# i = 0
# while i < len(l):
#   print(l[i])
#   i += 1

# example for | while
# d = {"name":"helo","age":20,"phone":"00000000"}
# l = d.keys()
# print(l)
# for i in range(len(d.keys())):
#   print(i)


# list example
l = [10,[11,12,13,14,15]]
# print(l[1])

# for i in l[1]:
#   print(i)

# print("second approch")

# for i in range(2,len(l[1])):
#    print(l[1][i])


# break
# for i in range(5):
#   if i == 2:
#     break
#   print(i)


# continue
# i = 0
# while True:
#   print(i)
#   if i == 5:
#     break
#   else:
#     i += 1
#     continue

# pass
i = 0
while True:
  print(i)
  if i == 4:
    pass
  if i == 5:
    break
  else:
    i += 1
    continue
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **5 Questions on Conditional statement and loops**

# %% [markdown]
# 1. ATM Withdrawl System

# %%
# 1. ATM Withdrawal System
balance = 10000

while True:
    amount = int(input("Enter withdrawal amount: "))

    if amount == 0:
        break

    if amount <= balance:
        balance -= amount
        print("Remaining Balance:", balance)
    else:
        print("Insufficient Balance")
# Out:
# Enter withdrawal amount: 1
# Remaining Balance: 9999
# Enter withdrawal amount: 0

# %% [markdown]
# 2. Student Result Analyzer

# %%
# 2. Student Result Analyzer
passed = 0
failed = 0

for i in range(1, 6):
    marks = int(input(f"Enter marks of student {i}: "))

    if marks >= 40:
        print("Pass")
        passed += 1
    else:
        print("Fail")
        failed += 1

print("Total Passed:", passed)
print("Total Failed:", failed)
# Out:
# Enter marks of student 1: 0
# Fail
# Enter marks of student 2: 0
# Fail
# Enter marks of student 3: 1
# Fail
# Enter marks of student 4: 6
# Fail
# Enter marks of student 5: 468
# Pass
# Total Passed: 1
# Total Failed: 4

# %% [markdown]
# 3. Password Retry System

# %%
# 3. Password Retry System
password = "python123"
attempts = 0

while attempts < 3:
    user = input("Enter password: ")

    if user == password:
        print("Login Successful")
        break
    else:
        print("Wrong Password")

    attempts += 1

if attempts == 3:
    print("Account Locked")
# Out:
# Enter password: 86
# Wrong Password
# Enter password: 1
# Wrong Password
# Enter password: 1
# Wrong Password
# Account Locked

# %% [markdown]
# 4. Electricity Bill Calculator

# %%
# 4. Electricity Bill Calculator

for i in range(1, 4):
    units = int(input(f"Enter units for customer {i}: "))

    if units <= 100:
        bill = units * 5
    elif units <= 200:
        bill = (100 * 5) + ((units - 100) * 7)
    else:
        bill = (100 * 5) + (100 * 7) + ((units - 200) * 10)

    print("Bill Amount:", bill)
# Out:
# Enter units for customer 1: 4
# Bill Amount: 20
# Enter units for customer 2: -0
# Bill Amount: 0
# Enter units for customer 3: 1
# Bill Amount: 5

# %% [markdown]
# 5. Number Guessing Game

# %%
# 5. Number Guessing Game

secret = 25
attempts = 0

while True:
    guess = int(input("Enter your guess: "))
    attempts += 1

    if guess > secret:
        print("Too High")
    elif guess < secret:
        print("Too Low")
    else:
        print("Correct Guess")
        print("Attempts:", attempts)
        break
# Out:
# Enter your guess: 2
# Too Low
# Enter your guess: 1
# Too Low
# Enter your guess: 6
# Too Low
# Enter your guess: 769
# Too High
# Enter your guess: 47
# Too High
# Enter your guess: 0
# Too Low
# Enter your guess: 1
# Too Low
# Enter your guess: 536
# Too High
# Enter your guess: 3654
# Too High
# Enter your guess: 756
# Too High
# Enter your guess: 23
# Too Low
# Enter your guess: 45
# Too High
# Enter your guess: 24
# Too Low
# Enter your guess: 34
# Too High
# Enter your guess: 30
# Too High
# Enter your guess: 28
# Too High
# Enter your guess: 27
# Too High
# Enter your guess: 26
# Too High
# Enter your guess: 25
# Correct Guess
# Attempts: 19
